# %% [markdown]
# ## Contents of the Notebook:
#
# #### Part1: Exploratory Data Analysis(EDA):
# 1)Analysis of the features.
#
# 2)Finding any relations or trends considering multiple features.
# #### Part2: Feature Engineering and Data Cleaning:
# 1)Adding any few features.
#
# 2)Removing redundant features.
#
# 3)Converting features into suitable form for modeling.

# %% [markdown]
# ## Part1: Exploratory Data Analysis(EDA)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
data = pd.read_csv('taitanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # C = Cherbourg, Q = Queenstown, S = Southampton

# %%
data.isnull().sum() #checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# The **Age, Cabin and Embarked** have null values. I will try to fix them.

# %% [markdown]
# ### How many Survived??

# %%
data['Survived'].value_counts() # 0 = Not Survived, 1 = Survived
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Survived'].value_counts().plot.pie(autopct='%.2f%%', shadow=True) # autopct will show percentage in float value as it's a pie chart
plt.title('Survived Percentage and Not Survived Percentage')
plt.show()

# %%
datalebel = sns.countplot(x=data['Survived'])
plt.title('Survived vs Not Survived')

for i in datalebel.containers:
    datalebel.bar_label(i, fmt='%.f', label_type='edge')

plt.show()

# %%
datalabel=sns.countplot(x=data['Survived'])
plt.title('Survived vs Not Survived')
plt.xticks(ticks=[0,1], labels=['Not Survived', 'Survived'])
plt.xlabel('Number of People')
plt.ylabel('Frequency')
plt.yticks(np.arange(0, 601, 100))
plt.tight_layout()

for i in datalabel.containers:
    datalabel.bar_label(i)
plt.show()

# %%
f,axe = plt.subplots(1, 2, figsize=(12,5))
data['Survived'].value_counts().plot.pie(autopct='%.2f%%', ax=axe[0], shadow=True)
axe[0].set_title('Percentage')

datalabel= sns.countplot(x=data['Survived'], ax=axe[1], hue="Sex",data=data)
axe[1].set_title('Survived vs Not Survived')
for i in datalabel.containers:
    datalabel.bar_label(i,)

plt.title('Survived vs Not Survived')
plt.xticks(ticks=[0,1], labels=['Not Survived', 'Survived'])
plt.xlabel('Number of People Based on Sex')
plt.ylabel('Frequency')
plt.yticks(np.arange(0, 601, 100))
plt.tight_layout()

# %% [markdown]
# ## Types Of Features
#
# ### Nominal Features:
# A categorical variable is one that has two or more categories and each value in that feature can be categorised by them.For example, gender is a categorical variable having two categories (male and female). Now we cannot sort or give any ordering to such variables.
#
# **Nominal Features in the dataset: Sex,Embarked.**
#
# ### Ordinal Features:
# An ordinal variable is similar to categorical values, but the difference between them is that we can have relative ordering or sorting between the values. For eg: If we have a feature like **Height** with values **Tall, Medium, Short**, then Height is a ordinal variable. Here we can have a relative sort in the variable.
#
# **Ordinal Features in the dataset: PClass**
#
# ### Continous Feature:
# A feature is said to be continous if it can take values between any two points or between the minimum or maximum values in the features column.
#
# **Continous Features in the dataset: Age**

# %% [markdown]
# ## Analysing The Features

# %% [markdown]
# ## Sex--> Categorical Feature

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
data[['Sex','Survived']].groupby(['Sex']).mean() # As Survived is in 0 and 1, we can use mean to get the percentage of survived people. Result would indicate the percentage of survived people.
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# ### How many Survived based on Sex??

# %%
f,ax=plt.subplots(1,2,figsize=(12,5))

datalabel=data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
for i in datalabel.containers:
    datalabel.bar_label(i)
ax[0].set_title('Survival Rate')

datalabel=sns.countplot(y='Sex',hue="Survived", data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
for i in datalabel.containers:
    datalabel.bar_label(i)
plt.show()

# %% [markdown]
# This looks interesting. The number of men on the ship is lot more than the number of women. Still the number of women saved is almost twice the number of males saved. The survival rates for a **women on the ship is around 75% while that for men in around 18-19%.**
#
# This looks to be a **very important** feature for modeling. But is it the best??   Lets check other features.

# %% [markdown]
# ## Pclass --> Ordinal Feature

# %%
pd.crosstab(data.Pclass, data.Survived) # crosstab is used to get the frequency of the data
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(data.Survived, data.Pclass) # same as : pd.crosstab(data.Pclass, data.Survived).T
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %% [markdown]
# ### How many Survived based on Pclass??

# %%
# Create subplots
f, ax = plt.subplots(1, 2, figsize=(12, 5))

# First plot: Bar chart of passengers by class
datalabel = data['Pclass'].value_counts().plot.bar(color=['#75FA8D', '#FFDF00', '#D3D3D3'], ax=ax[0])
for i in datalabel.containers:
    ax[0].bar_label(i)  # Add bar labels
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count of Passengers')

# Second plot: Countplot of survived vs dead by Pclass
datalabel = sns.countplot(x='Pclass', hue='Survived', data=data, ax=ax[1])
for i in datalabel.containers:
    ax[1].bar_label(i)  # Add bar labels

# Set x-axis labels explicitly
ax[1].set_xticks([0, 1, 2])  # Positions of the ticks
ax[1].set_xticklabels(['1st Class', '2nd Class', '3rd Class'])  # Labels for the ticks

# Set y-axis ticks
ax[1].set_yticks(np.arange(0, 401, 50))  # Set y-axis ticks from 0 to 400 in steps of 50

# Set legend labels explicitly
ax[1].legend(title='Survived', labels=['Not Survived', 'Survived'])

ax[1].set_title('Pclass: Survived vs Dead')
ax[1].set_ylabel('Count of Passengers')

plt.show()

# %% [markdown]
# People say **Money Can't Buy Everything**. But we can clearly see that Passenegers Of Pclass 1 were given a very high priority while rescue. Even though the the number of Passengers in Pclass 3 were a lot higher, still the number of survival from them is very low, somewhere around **25%**.
#
# For Pclass 1 survived is around **63%** while for Pclass2 is around **48%**. So money and status matters. Such a materialistic world.
#
# Lets Dive in little bit more and check for other interesting observations. Lets check survival rate with **Sex and Pclass** Together.

# %%
pd.crosstab(data.Survived, data.Pclass)
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass)
# Out:
# Pclass            1   2    3
# Sex    Survived
# female 0          3   6   72
#        1         91  70   72
# male   0         77  91  300
#        1         45  17   47

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass).plot.bar()
plt.xlabel('Sex and Survival Status')
plt.show()

# %%
# Create a categorical bar plot with separate subplots for each Pclass
sns.catplot(
    x="Sex", 
    y="Survived", 
    col="Pclass",  # Separate subplots for each Pclass
    kind="bar",   # Bar plot
    data=data, 
    palette='deep',  # Color palette
    height=4,            # Height of each subplot
    aspect=0.8           # Width of each subplot
)

# Add a title to the entire figure
plt.suptitle('Survival Rate by Sex and Passenger Class', y=1.02)

# Show the plot
plt.show()

# %%
sns.catplot(x="Sex", y="Survived", col="Pclass", kind="point", data=data)
    
plt.show()

# %% [markdown]
# We can easily infer that survival for **Women from Pclass1** is about **95-96%**, as only 3 out of 94 Women from Pclass1 died.
#
# It is evident that irrespective of Pclass, Women were given first priority while rescue. Even Men from Pclass1 have a very low survival rate.
#
# Looks like Pclass is also an important feature. Lets analyse other features.

# %% [markdown]
# ## Age--> Continous Feature

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
# violin plot
f,ax=plt.subplots(figsize=(10,5))
sns.violinplot(x="Pclass",y="Age", data=data, ax=ax)
ax.set_title('Pclass and Age')
ax.set_yticks(range(0,110,10))
plt.show()

# %%
# violin plot
f,ax=plt.subplots(figsize=(10,8))
sns.violinplot(x="Pclass",y="Age", hue="Survived", data=data, ax=ax)
ax.set_title('Pclass and Age')
ax.set_yticks(range(0,91,10))
plt.show()

# %%
# violin plot
f,ax=plt.subplots(figsize=(10,5))
sns.violinplot(x="Pclass",y="Age", hue="Survived",split=True, data=data, ax=ax)
ax.set_title('Pclass and Age')
ax.set_yticks(range(0,91,10))
plt.show()

# %%
# violin plot
f,ax=plt.subplots(1,2,figsize=(12,5))
sns.violinplot(x="Pclass",y="Age", hue="Survived", data=data, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))

sns.violinplot(x="Sex",y="Age", hue="Survived", data=data, split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# #### Observations:
#
# 1)The number of children increases with Pclass and the survival rate for passenegers below Age 10(i.e children) looks to be good irrespective of the Pclass.
#
# 2)Survival chances for Passenegers aged 20-50 from Pclass1 is high and is even better for Women.
#
# 3)For males, the survival chances decreases with an increase in age.

# %% [markdown]
# As we had seen earlier, the Age feature has **177** null values. To replace these NaN values, we can assign them the mean age of the dataset.
#
# But the problem is, there were many people with many different ages. We just cant assign a 4 year kid with the mean age that is 29 years. Is there any way to find out what age-band does the passenger lie??
#
# **Bingo!!!!**, we can check the **Name**  feature. Looking upon the feature, we can see that the names have a salutation like Mr or Mrs. Thus we can assign the mean values of Mr and Mrs to the respective groups.
#
# **''What's In A Name??''**---> **Feature**  :p

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data['Initial'] = 'other'
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
for i in data:
    data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.') # It will extract the initials from the name and store it in the Initial column

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Okay so here we are using the Regex: **[A-Za-z]+)\.**. So what it does is, it looks for strings which lie between **A-Z or a-z** and followed by a **.(dot)**. So we successfully extract the Initials from the Name.

# %%
pd.crosstab(data.Initial, data.Sex)
# Out:
# Sex       female  male
# Initial
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
pd.crosstab(data.Initial, data.Sex).T
# Out:
# Initial  Capt  Col  Countess  Don  Dr  Jonkheer  Lady  Major  Master  Miss  \
# Sex
# female      0    0         1    0   1         0     1      0       0   182
# male        1    2         0    1   6         1     0      2      40     0
#
# Initial  Mlle  Mme   Mr  Mrs  Ms  Rev  Sir
# Sex
# female      2    1    0  125   1    0    0
# male        0    0  517    0   0    6    1

# %%
pd.crosstab(data.Initial, data.Sex).T 
#Checking the Initials with the Sex
# Out:
# Initial  Capt  Col  Countess  Don  Dr  Jonkheer  Lady  Major  Master  Miss  \
# Sex
# female      0    0         1    0   1         0     1      0       0   182
# male        1    2         0    1   6         1     0      2      40     0
#
# Initial  Mlle  Mme   Mr  Mrs  Ms  Rev  Sir
# Sex
# female      2    1    0  125   1    0    0
# male        0    0  517    0   0    6    1

# %%
pd.crosstab(data.Initial, data.Sex).T.style.background_gradient()
# Out:
# <style type="text/css">
# #T_0798b_row0_col0, #T_0798b_row0_col1, #T_0798b_row0_col3, #T_0798b_row0_col4, #T_0798b_row0_col5, #T_0798b_row0_col7, #T_0798b_row0_col8, #T_0798b_row0_col12, #T_0798b_row0_col15, #T_0798b_row0_col16, #T_0798b_row1_col2, #T_0798b_row1_col6, #T_0798b_row1_col9, #T_0798b_row1_col10, #T_0798b_row1_col11, #T_0798b_row1_col13, #T_0798b_row1_col14 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0798b_row0_col2, #T_0798b_row0_col6, #T_0798b_row0_col9, #T_0798b_row0_col10, #T_0798b_row0_col11, #T_0798b_row0_col13, #T_0798b_row0_col14, #T_0798b_row1_col0, #T_0798b_row1_col1, #T_0798b_row1_col3, #T_0798b_row1_col4, #T_0798b_row1_col5, #T_0798b_row1_col7, #T_0798b_row1_col8, #T_0798b_row1_col12, #T_0798b_row1_col15, #T_0798b_row1_col16 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0798b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
# ...

# %% [markdown]
# Okay so there are some misspelled Initials like Mlle or Mme that stand for Miss. I will replace them with Miss and same thing for other values.

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Mr','Mr','Mr','Mr','Mr','Mr'],
                        inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.Initial.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master'], dtype=object)

# %%
pd.crosstab(data.Initial, data.Sex).T.style.background_gradient()
# Out:
# <style type="text/css">
# #T_8c7a6_row0_col0, #T_8c7a6_row0_col2, #T_8c7a6_row1_col1, #T_8c7a6_row1_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_8c7a6_row0_col1, #T_8c7a6_row0_col3, #T_8c7a6_row1_col0, #T_8c7a6_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8c7a6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_8c7a6_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_8c7a6_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_8c7a6_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_8c7a6_level0_col3" class="col_heading level0 col3" >Mrs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
# ...

# %%
data.groupby('Initial')['Age'].mean() #lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        33.022727
# Mrs       35.981818
# Name: Age, dtype: float64

# %% [markdown]
# ### Filling NaN Ages

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Initial          0
# dtype: int64

# %%
data.loc[(data.Age.isnull())&(data.Initial=='Mr')]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex  Age  \
# 5              6         0       3              Moran, Mr. James  male  NaN
# 17            18         1       2  Williams, Mr. Charles Eugene  male  NaN
# 26            27         0       3       Emir, Mr. Farred Chehab  male  NaN
# 29            30         0       3           Todoroff, Mr. Lalio  male  NaN
# 36            37         1       3              Mamee, Mr. Hanna  male  NaN
# ..           ...       ...     ...                           ...   ...  ...
# 839          840         1       1          Marechal, Mr. Pierre  male  NaN
# 846          847         0       3      Sage, Mr. Douglas Bullen  male  NaN
# 859          860         0       3              Razi, Mr. Raihed  male  NaN
# 868          869         0       3   van Melkebeke, Mr. Philemon  male  NaN
# 878          879         0       3            Laleff, Mr. Kristo  male  NaN
#
# ...

# %%
## Assigning the NaN Values with the Ceil values of the mean ages
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33 # we can use the code to fill the missing values in the Age column
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data.Age.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Another method

# %%
# Calculate the mean age for each 'Initial' group
mean_ages = data.groupby('Initial')['Age'].transform('mean')

# Fill missing 'Age' values with the corresponding mean age for each 'Initial' group
data.loc[data['Age'].isnull(), 'Age'] = mean_ages

# Verify the result
print(data.groupby('Initial')['Age'].mean())
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        33.022727
# Mrs       35.981818
# Name: Age, dtype: float64

# %%
data.Age.isnull().sum()
# Out:
# np.int64(0)

# %%
# Create subplots
f, ax = plt.subplots(1, 2, figsize=(20, 10))

# First subplot: Histogram for Survived = 0
data[data['Survived'] == 0].Age.plot.hist(ax=ax[0], bins=20, edgecolor='black') 
ax[0].set_title('Survived = 0')
ax[0].set_xlabel('Age')  # Fix: Use set_xlabel
ax[0].set_ylabel('Frequency')  # Fix: Use set_ylabel
x_ticks = list(range(0, 85, 5))  # Simplify x-axis ticks
ax[0].set_xticks(x_ticks)

# Second subplot: Histogram for Survived = 1
data[data['Survived'] == 1].Age.plot.hist(ax=ax[1], bins=20, edgecolor='black', color='green')
ax[1].set_title('Survived = 1')
ax[1].set_xlabel('Age')  # Add x-label for the second subplot
ax[1].set_ylabel('Frequency')  # Add y-label for the second subplot
ax[1].set_xticks(x_ticks)  # Use the same x-axis ticks

# Show the plot
plt.show()

# %%
data[data.Age == 80]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked Initial
# 630  male  80.0      0      0  27042  30.0   A23        S      Mr

# %% [markdown]
# ### Observations:
# 1)The Toddlers(age<5) were saved in large numbers(The Women and Child First Policy).
#
# 2)The oldest Passenger was saved(80 years).
#
# 3)Maximum number of deaths were in the age group of 30-40.

# %%
sns.catplot(x="Pclass", y="Survived", col="Initial", kind="point", data=data)

# Customize x-axis tick labels
plt.xticks(ticks=[0, 1, 2], labels=['1st Class', '2nd Class', '3rd Class'])

# Add a title to the entire figure
plt.suptitle('Survival Rate by Initial and Passenger Class', y=1.02)

# Show the plot
plt.show()

# %% [markdown]
# The Women and Child first policy thus holds true irrespective of the class.

# %% [markdown]
# ### Chances for Survival by Port Of Embarkation

# %%
data.Embarked.value_counts() # Embarked indicates the port of embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
sns.catplot(x='Embarked',y='Survived', kind="point", data=data)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
# Create a figure and axis
f, ax = plt.subplots(figsize=(12, 5))

# Use sns.pointplot (axes-level function) to plot the data
sns.pointplot(x='Embarked', y='Survived', data=data, ax=ax)

# Set title and labels
ax.set_title('Survival Rate by Embarked Port')
ax.set_xlabel('Embarked Port')
ax.set_ylabel('Survival Rate')

# Show the plot
plt.show()

# %% [markdown]
# The chances for survival for Port C is highest around 0.55 while it is lowest for S.

# %%
help(plt.subplots()) # to get the help of the function
# Out:
# Help on tuple object:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
#  |      UnraisableHookArgs
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
# ...

# %%
# Create a 2x2 grid of subplots
f, ax = plt.subplots(2, 2, figsize=(12, 7))

# Plot 1: Number of Passengers Boarded
sns.countplot(x='Embarked', data=data, ax=ax[0, 0])
for container in ax[0, 0].containers:
    ax[0, 0].bar_label(container)
ax[0, 0].set_title('No. Of Passengers Boarded')

# Plot 2: Male-Female Split for Embarked
sns.countplot(x='Embarked', hue='Sex', data=data, ax=ax[0, 1])
for container in ax[0, 1].containers:
    ax[0, 1].bar_label(container)
ax[0, 1].set_title('Male-Female Split for Embarked')

# Plot 3: Embarked vs Survived
sns.countplot(x='Embarked', hue='Survived', data=data, ax=ax[1, 0])
for container in ax[1, 0].containers:
    ax[1, 0].bar_label(container)
ax[1, 0].set_title('Embarked vs Survived')

# Plot 4: Embarked vs Pclass
sns.countplot(x='Embarked', hue='Pclass', data=data, ax=ax[1, 1], palette='deep')
for container in ax[1, 1].containers:
    ax[1, 1].bar_label(container)
ax[1, 1].set_title('Embarked vs Pclass')

# Adjust subplot spacing
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Observations:
# 1)Maximum passenegers boarded from S. Majority of them being from Pclass3.
#
# 2)The Passengers from C look to be lucky as a good proportion of them survived. The reason for this maybe the rescue of all the Pclass1 and Pclass2 Passengers.
#
# 3)The Embark S looks to the port from where majority of the rich people boarded. Still the chances for survival is low here, that is because many passengers from Pclass3 around **81%** didn't survive.
#
# 4)Port Q had almost 95% of the passengers were from Pclass3.

# %%
# sns.catplot(x='Embarked',y='Survived', kind="point", data=data)

sns.catplot(x='Pclass',y='Survived',hue='Sex',col='Embarked', kind="point", data=data)
plt.show()

# %% [markdown]
# ### Observations:
#
# 1)The survival chances are almost 1 for women for Pclass1 and Pclass2 irrespective of the Pclass.
#
# 2)Port S looks to be very unlucky for Pclass3 Passenegers as the survival rate for both men and women is very low.**(Money Matters)**
#
# 3)Port Q looks looks to be unlukiest for Men, as almost all were from Pclass 3.

# %% [markdown]
# ### Filling Embarked NaN
#
# As we saw that maximum passengers boarded from Port S, we replace NaN with S.

# %%
data['Embarked'].isnull().sum()
# Out:
# np.int64(2)

# %%
data['Embarked'].fillna('S', inplace=True)

# %%
data.Embarked.isnull().sum()# Finally No NaN values
# Out:
# np.int64(0)

# %% [markdown]
# ## SibSp-->Discrete Feature
# This feature represents whether a person is alone or with his family members.
#
# Sibling = brother, sister, stepbrother, stepsister
#
# Spouse = husband, wife

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_97b84_row0_col0, #T_97b84_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_97b84_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_97b84_row1_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_97b84_row2_col0, #T_97b84_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_97b84_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_97b84_row3_col0, #T_97b84_row3_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_97b84_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_97b84_row5_col0, #T_97b84_row5_col1, #T_97b84_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_97b84_row6_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_97b84">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
# ...

# %%
sns.barplot(x='SibSp', y='Survived',data=data)
sns.catplot(x='SibSp',y='Survived', kind="point", data=data)

# plt.close(1) # to close the first plot
plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_69041_row0_col0, #T_69041_row0_col1, #T_69041_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_69041_row1_col0 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_69041_row1_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_69041_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_69041_row2_col0, #T_69041_row4_col2 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_69041_row2_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_69041_row2_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_69041_row3_col0, #T_69041_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_69041_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_69041_row4_col0, #T_69041_row4_col1, #T_69041_row5_col0, #T_69041_row5_col1, #T_69041_row5_col2, #T_69041_row6_col0, #T_69041_row6_col1 {
#   background-color: #ffff66;
# ...

# %% [markdown]
# ### Observations:
#
#
# The barplot and factorplot shows that if a passenger is alone onboard with no siblings, he have 34.5% survival rate. The graph roughly decreases if the number of siblings increase. This makes sense. That is, if I have a family on board, I will try to save them instead of saving myself first. Surprisingly the survival for families with 5-8 members is **0%**. The reason may be Pclass??
#
# The reason is **Pclass**. The crosstab shows that Person with SibSp>3 were all in Pclass3. It is imminent that all the large families in Pclass3(>3) died.

# %% [markdown]
# ## Fare--> Continous Feature

# %%
print('Highest Fare was:',data['Fare'].max())
print('Lowest Fare was:',data['Fare'].min())
print('Average Fare was:',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.204207968574636

# %% [markdown]
# The lowest fare is **0.0**. Wow!! a free luxorious ride.

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0]) # displot is used to plot the distribution of the data. Here we are plotting the distribution of Fare for Pclass 1
ax[0].set_title('Fares in Pclass 1')

sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')

sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')

plt.show()

# %% [markdown]
# There looks to be a large distribution in the fares of Passengers in Pclass1 and this distribution goes on decreasing as the standards reduces. As this is also continous, we can convert into discrete values by using binning.

# %% [markdown]
# ## Observations in a Nutshell for all features:
# **Sex:** The chance of survival for women is high as compared to men.
#
# **Pclass:** There is a visible trend that being a **1st class passenger** gives you better chances of survival. The survival rate for **Pclass3 is very low**. For **women**, the chance of survival from **Pclass1** is almost 1 and is high too for those from **Pclass2**.   **Money Wins!!!**.
#
# **Age:** Children less than 5-10 years do have a high chance of survival. Passengers between age group 15 to 35 died a lot.
#
# **Embarked:** This is a very interesting feature. **The chances of survival at C looks to be better than even though the majority of Pclass1 passengers got up at S.** Passengers at Q were all from **Pclass3**.
#
# **SibSp:** Having 1-2 siblings,spouse on board or 1-3 Parents shows a greater chance of probablity rather than being alone or having a large family travelling with you.

# %% [markdown]
# ## Correlation Between The Features

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
#  12  Initial      891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
data2 = data[['Survived','Age','Pclass', 'SibSp', 'Parch', 'Fare']]

# %%
data2.corr()
# Out:
#           Survived       Age    Pclass     SibSp     Parch      Fare
# Survived  1.000000 -0.091829 -0.338481 -0.035322  0.081629  0.257307
# Age      -0.091829  1.000000 -0.339723 -0.268224 -0.198846  0.089069
# Pclass   -0.338481 -0.339723  1.000000  0.083081  0.018443 -0.549500
# SibSp    -0.035322 -0.268224  0.083081  1.000000  0.414838  0.159651
# Parch     0.081629 -0.198846  0.018443  0.414838  1.000000  0.216225
# Fare      0.257307  0.089069 -0.549500  0.159651  0.216225  1.000000

# %%
sns.heatmap(data2.corr(),annot=True,cmap='RdYlGn',linewidths=0.3) #data.corr()-->correlation matrix; cmap is used to set the color of the heatmap; annot = True to annotate the heatmap; linewidths=0.3 is used to set the width of the lines in the heatmap

fig=plt.gcf()
fig.set_size_inches(12,5)
plt.show()

# %% [markdown]
# ### Interpreting The Heatmap
#
# The first thing to note is that only the numeric features are compared as it is obvious that we cannot correlate between alphabets or strings. Before understanding the plot, let us see what exactly correlation is.
#
# **POSITIVE CORRELATION:** If an **increase in feature A leads to increase in feature B, then they are positively correlated**. A value **1 means perfect positive correlation**.
#
# **NEGATIVE CORRELATION:** If an **increase in feature A leads to decrease in feature B, then they are negatively correlated**. A value **-1 means perfect negative correlation**.
#
# Now lets say that two features are highly or perfectly correlated, so the increase in one leads to increase in the other. This means that both the features are containing highly similar information and there is very little or no variance in information. This is known as **MultiColinearity** as both of them contains almost the same information.
#
# So do you think we should use both of them as **one of them is redundant**. While making or training models, we should try to eliminate redundant features as it reduces training time and many such advantages.
#
# Now from the above heatmap,we can see that the features are not much correlated. The highest correlation is between **SibSp and Parch i.e 0.41**. So we can carry on with all features.

# %% [markdown]
# ## Part2: Feature Engineering and Data Cleaning
#
# Now what is Feature Engineering?
#
# Whenever we are given a dataset with features, it is not necessary that all the features will be important. There maybe be many redundant features which should be eliminated. Also we can get or add new features by observing or extracting information from other features.
#
# An example would be getting the Initals feature using the Name Feature. Lets see if we can get any new features and eliminate a few. Also we will tranform the existing relevant features to suitable form for Predictive Modeling.

# %% [markdown]
# ## Age_band
#
# #### Problem With Age Feature:
# As I have mentioned earlier that **Age is a continous feature**, there is a problem with Continous Variables in Machine Learning Models.
#
# **Eg:** If I say to group or arrange Sports Person by **Sex**, We can easily segregate them by Male and Female.
#
# Now if I say to group them by their **Age**, then how would you do it? If there are 30 Persons, there may be 30 age values. Now this is problematic.
#
# We need to convert these **continous values into categorical values** by either Binning or Normalisation. I will be using binning i.e group a range of ages into a single bin or assign them a single value.
#
# Okay so the maximum age of a passenger was 80. So lets divide the range from 0-80 into 5 bins. So 80/5=16.
# So bins of size 16.

# %%
data['Age_band']=0
data.loc[data['Age']<=16,'Age_band']=0
data.loc[(data['Age']>16)&(data['Age']<=32),'Age_band']=1
data.loc[(data['Age']>32)&(data['Age']<=48),'Age_band']=2
data.loc[(data['Age']>48)&(data['Age']<=64),'Age_band']=3
data.loc[data['Age']>64,'Age_band']=4
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0         A/5 21171   7.2500   NaN        S      Mr         1
# 1      0          PC 17599  71.2833   C85        C     Mrs         2
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Miss         1
# ...

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer') #checking the number of passenegers in each band; cmap is the color of the gradient; style.background_gradient(cmap='summer') is used to set the background color of the table; to_frame() is used to convert the series to dataframe; value_counts() is used to get the frequency of the data;
# Out:
# <style type="text/css">
# #T_63ad8_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_63ad8_row1_col0 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_63ad8_row2_col0 {
#   background-color: #40a066;
#   color: #f1f1f1;
# }
# #T_63ad8_row3_col0 {
#   background-color: #289366;
#   color: #f1f1f1;
# }
# #T_63ad8_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_63ad8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63ad8_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age_band</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63ad8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_63ad8_row0_col0" class="data row0 col0" >382</td>
#     </tr>
#     <tr>
# ...

# %%
# Create a categorical point plot
figure = sns.catplot(
    x='Age_band',  
    y='Survived', 
    data=data, 
    col='Pclass',  # Separate subplots for each Pclass
    kind='point',  # Use point plot
    height=4,     # Corrected: Use 'height' instead of 'heifight'
    aspect=1.2    # Width of each subplot
)

# Add a title to the entire figure
figure.fig.suptitle('Age Band vs Survival Rate by Passenger Class', y=1.02)  

# Adjust layout to prevent title overlap
plt.tight_layout()  

# Show the plot
plt.show()

# %% [markdown]
# True that..the survival rate decreases as the age increases irrespective of the Pclass.
#
# ## Family_Size and Alone
# At this point, we can create a new feature called "Family_size" and "Alone" and analyse it. This feature is the summation of Parch and SibSp. It gives us a combined data so that we can check if survival rate have anything to do with family size of the passengers. Alone will denote whether a passenger is alone or not.

# %%
data['Family_Size']=0
data['Family_Size']=data['Parch']+data['SibSp'] # family size is the combination of Parch and SibSp
data['Alone']=0
data.loc[data.Family_Size==0,'Alone']=1 # Alone is the person who is not with family

# f,ax=plt.subplots(1,2,figsize=(18,6))
sns.catplot(x='Family_Size', y ='Survived',data=data, kind='point')
ax[0].set_title('Family_Size vs Survived')
sns.catplot(x='Alone',y='Survived',data=data,kind='point')
ax[1].set_title('Alone vs Survived')
# plt.close(2)
# plt.close(3)
plt.show()

# %%
# Create Family_Size column
data['Family_Size'] = data['Parch'] + data['SibSp']

# Create Alone column
data['Alone'] = 0
data.loc[data['Family_Size'] == 0, 'Alone'] = 1  # 1 = Alone, 0 = With Family

print(data[['Family_Size', 'Alone']].head())

# Create subplots
f, ax = plt.subplots(1, 2, figsize=(18, 6))

# Plot 1: Family_Size vs Survived
sns.pointplot(x='Family_Size', y='Survived', data=data, ax=ax[0])
ax[0].set_title('Family_Size vs Survived')
ax[0].set_xlabel('Family Size')
ax[0].set_ylabel('Survival Rate')

# Plot 2: Alone vs Survived
sns.pointplot(x='Alone', y='Survived', data=data, ax=ax[1])
ax[1].set_title('Alone vs Survived')
ax[1].set_xlabel('Alone (1 = Yes, 0 = No)')
ax[1].set_ylabel('Survival Rate')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
#    Family_Size  Alone
# 0            1      0
# 1            1      0
# 2            0      1
# 3            1      0
# 4            0      1

# %% [markdown]
# **Family_Size=0 means that the passeneger is alone.** Clearly, if you are alone or family_size=0,then chances for survival is very low. For family size > 4,the chances decrease too. This also looks to be an important feature for the model. Lets examine this further.

# %%
sns.catplot(x='Alone',y='Survived',data=data,hue='Sex',col='Pclass',kind='point')
plt.show()

# %% [markdown]
# It is visible that being alone is harmful irrespective of Sex or Pclass except for Pclass3 where the chances of females who are alone is high than those with family.
#
# ## Fare_Range
#
# Since fare is also a continous feature, we need to convert it into ordinal value. For this we will use **pandas.qcut**.
#
# So what **qcut** does is it splits or arranges the values according the number of bins we have passed. So if we pass for 5 bins, it will arrange the values equally spaced into 5 seperate bins or value ranges.

# %%
data['Fare_Range'] = pd.qcut(data['Fare'], 4) # qcut is used to quantile-based discretization function. qcut bins the data based on sample quantiles. For example 1000 values for 4 quantiles would produce a categorical object indicating quantile membership for each data point. Here we are using 5 quantiles to see the fare range of the data. Survived  includes the information of the people who survived and the people who did not survive.
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r') # Survived.mean() will give the percentage of people who survived. style.background_gradient(cmap='summer_r') is used to set the background color of the table.
# Out:
# <style type="text/css">
# #T_6a54b_row0_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_6a54b_row1_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_6a54b_row2_col0 {
#   background-color: #7ebe66;
#   color: #000000;
# }
# #T_6a54b_row3_col0 {
#   background-color: #72b866;
#   color: #f1f1f1;
# }
# #T_6a54b_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6a54b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a54b_level0_col0" class="col_heading level0 col0" >Survived</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fare_Range</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a54b_level0_row0" class="row_heading level0 row0" >(-0.001, 7.854]</th>
#       <td id="T_6a54b_row0_col0" class="data row0 col0" >0.217877</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# As discussed above, we can clearly see that as the **fare_range increases, the chances of survival increases.**
#
# Now we cannot pass the Fare_Range values as it is. We should convert it into singleton values same as we did in **Age_Band**

# %%
data['Fare_cat']=0 # Fare_cat is the category of the fare
data.loc[data['Fare']<=7.91,'Fare_cat']=0
data.loc[(data['Fare']>7.91)&(data['Fare']<=14.454),'Fare_cat']=1
data.loc[(data['Fare']>14.454)&(data['Fare']<=31),'Fare_cat']=2
data.loc[(data['Fare']>31)&(data['Fare']<=513),'Fare_cat']=3

# %%
sns.catplot(x='Fare_cat',y='Survived',data=data,hue='Sex', kind='point')
plt.show()

# %% [markdown]
# Clearly, as the Fare_cat increases, the survival chances increases. This feature may become an important feature during modeling along with the Sex.
#
# ## Converting String Values into Numeric
#
# Since we cannot pass strings to a machine learning model, we need to convert features loke Sex, Embarked, etc into numeric values.

# %%
data['Sex'].replace(['male','female'],[0,1],inplace=True)
data['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
data['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)

# %% [markdown]
# ### Dropping UnNeeded Features
#
# **Name**--> We don't need name feature as it cannot be converted into any categorical value.
#
# **Age**--> We have the Age_band feature, so no need of this.
#
# **Ticket**--> It is any random string that cannot be categorised.
#
# **Fare**--> We have the Fare_cat feature, so unneeded
#
# **Cabin**--> A lot of NaN values and also many passengers have multiple cabins. So this is a useless feature.
#
# **Fare_Range**--> We have the fare_cat feature.
#
# **PassengerId**--> Cannot be categorised.

# %%
data.drop(['Name','Age','Ticket','Fare','Cabin','Fare_Range','PassengerId'],axis=1,inplace=True)
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# Now the above correlation plot, we can see some positively related features. Some of them being **SibSp andd Family_Size** and **Parch and Family_Size** and some negative ones like **Alone and Family_Size.**

# %%
# Save the cleaned DataFrame to a CSV file
data.to_csv('titanic_cleaned.csv', index=False)
